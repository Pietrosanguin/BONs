# %% [markdown]
# # NORM-0 FW ALIGNMENT
#
# In this notebook we provide the steps to do our alignment using amplepy module.
# For more references behind the math of the method see the thesis.
# Since we are using ampl syntax the data we are going to feed into the model must be in a suitable specific format.

# %%
from amplpy import AMPL, ampl_notebook

ampl = ampl_notebook(
    modules=["cplex"],  # modules to install
    license_uuid="your license",  # license to use
)  # instantiate AMPL object and register magics
# Out:
# Licensed to AMPL Community Edition License for <pietro.sanguin99@gmail.com>.

# %% [markdown]
# ## 1.1 Transforing the embedding matrices into .dat file in order to feed them to the ampl optimizer
#
# After running the script **Embeddings_creation.ipynb** we got three things:
#
# * a matrix containing the source embedding space vectors **X_source_embeddings_p2_0side_2959files.npy**
#
# * a matrix with the target space vectors **Y_target_embeddings_p2_2side_2959files.npy**
#
# * a dictionary of the word2id mapping between the words and the vectors **p2_0side_2959files_&_p2_2side_2959files_word2id.json**
#
# The following names must the same of the script **Embeddings_creation.ipynb**.

# %%
# TO MODIFY IF YOU WANT IF YOU CHANGED THE EMBEDDINGS
SOURCE_PREPROCESSED_TXT = 'p2_0side_2959files_preprocessed.txt'
TARGET_PREPROCESSED_TXT = 'p2_2side_2959files_preprocessed.txt'

SOURCE_PREPROCESSED_TXT = 'p1_0side_50files_preprocessed.txt'
TARGET_PREPROCESSED_TXT = 'p1_2side_50files_preprocessed.txt'

# %%
# SHOULD NOT BE MODIFIED
NAME_JSON_FILE = f'{SOURCE_PREPROCESSED_TXT.replace("preprocessed.txt", "")}' +'&_' + f'{TARGET_PREPROCESSED_TXT.replace("_preprocessed.txt", "")}' + "_word2id.json"
X_NAME = f'X_source_embeddings_{SOURCE_PREPROCESSED_TXT.replace("_preprocessed.txt", "")}'+'.npy'
Y_NAME = f'Y_target_embeddings_{TARGET_PREPROCESSED_TXT.replace("_preprocessed.txt", "")}'+'.npy'
W_NAME = 'W_' + (X_NAME.replace('X_', "")).replace('.npy', "") +'_' + Y_NAME.replace('Y_', "")

# %%
#DATA PREPROCESSING TO CREATE THE DATASET data.dat
#Metodo per scrivere file.dat per AMPL

import numpy as np

# Create a NumPy matrix
X = np.load(X_NAME)
Y = np.load(Y_NAME)  

#the transpose of X
X = X.T     
Y = Y.T

# Open the .dat file for writing
with open("data.dat", "w") as dat_file:
    #dat_file.write("set Rows;\n")
    #dat_file.write("set Columns;\n")
    #dat_file.write(f"set Rows := 1..{X.shape[0]};\n")  # Define a set of rows with labels 1, 2, 3
    #dat_file.write(f"set Columns := 1..{X.shape[1]};\n")  # Define a set of columns with labels 1, 2, 3
    
    dat_file.write("param x :=\n")

    # Define parameters and populate them with data
    #dat_file.write("param A{Rows, Columns};")

#data;

  
    # Write the matrix data
    for row in range(X.shape[0]):
        for col in range(X.shape[1]):
            dat_file.write(f"\t{row+1} {col+1} {X[row, col]}\n")
            if row == X.shape[0]-1 and col == X.shape[1]-1:
                dat_file.write(";")

    dat_file.write("param y :=\n")

        # Write the matrix data
    for row in range(Y.shape[0]):
        for col in range(Y.shape[1]):
            dat_file.write(f"\t{row+1} {col+1} {Y[row, col]}\n")
            if row == X.shape[0]-1 and col == X.shape[1]-1:
                dat_file.write(";")
    dat_file.write("end;")

# %%
ampl.read("FW.mod")

# %%
ampl.read_data("data.dat")

# %%
ampl.option["solver"] = "cplex"

# %% [markdown]
# ## NOTE BEFORE RUNNING THE AMPL OPTIMIZATION
# Check in the files **decomposition.mod** and **decomposition.run** the following
#
# J = K = X.shape[0]??
#
# I = X.shape[1]??
#
# it = X.shape[0]??

# %%
X.shape
# Out:
# (300, 4367)

# %%
ampl.read("decomposition.run")
# Out:
# CPLEX 22.1.1.0: optimal solution; objective 20.33833643
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 15.32252306
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 38.96798895
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 64.91945699
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 21.41685387
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 51.5608526
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 32.32598345
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 13.14430381
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 81.45757565
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 87.49321994
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 6.954577205
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 47.36902983
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 25.22973953
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 49.79372993
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 30.53174787
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 34.85161555
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 32.66223226
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 89.62882648
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 10.79968859
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 86.38788411
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 72.84973423
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 6.83848744
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 30.98895338
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 117.5236133
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 38.76507699
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 23.02858608
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 113.9046189
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 8.026792926
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 13.39441355
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 16.68503664
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 31.6113898
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 46.66511008
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 26.84825682
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 29.98701848
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 52.65512862
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 25.56168957
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 10.04869986
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 107.2647077
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 7.120488791
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 8.510083783
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 40.02838708
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.2262043
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 26.00407137
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 34.40566426
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 34.14667976
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 40.24801324
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 55.02352142
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 61.01539475
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 37.03751723
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 54.80811095
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 44.83585175
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 63.08953467
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 28.70707851
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 9.614878126
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 77.23801365
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 7.323394547
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 24.48792479
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 65.55801934
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 25.30343643
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 12.48258248
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 25.30603157
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 26.1325456
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 40.28479345
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 26.4213142
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.6774501
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 41.77236946
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.37799194
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 15.54066068
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 54.119132
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 29.24497879
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 10.29125057
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 56.26108132
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 21.61504714
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 15.72403942
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 44.82665137
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 24.06795874
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 68.6996257
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 22.75238283
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 12.39790505
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.30540386
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 21.09888887
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 38.10404576
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 36.39065057
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 8.080412715
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 15.58665643
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.30368082
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 16.9885874
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 45.83013069
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.66461761
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 20.10434442
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 23.35519945
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 58.70499969
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.73027681
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 69.85398658
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 65.38953742
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 43.24943134
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 7.491105777
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 20.32628809
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 27.85782711
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 15.15980781
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 39.95973598
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 23.92996979
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.97159368
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 18.42176089
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 30.51158318
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 54.71646792
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 23.63776518
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 37.94242989
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 71.58839005
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 43.2134348
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 35.73778977
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 24.73687798
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 7.767646909
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 20.02035774
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 17.30309001
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 18.35390195
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 14.76834462
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 7.441403214
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 133.8394564
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 119.7099408
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 27.33154877
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 72.97173558
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 7.937824288
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 18.89866092
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 13.75329693
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 22.26828944
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 26.11463064
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 60.4068942
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 32.30281397
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 34.78609727
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 28.85303873
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 23.02655609
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 54.56121242
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 12.42126583
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 27.57844792
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 31.38782342
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 76.58379687
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 41.97249205
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 16.7660277
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 57.88872012
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 38.48695076
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 14.00618296
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 22.74320631
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 42.57655946
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 35.56010495
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 73.86891551
# 0 dual simplex iterations (0 in phase I)
# 15 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 23.66807521
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 12.69855958
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 44.11248712
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 57.52427992
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 8.331619397
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 107.2780441
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 55.03401674
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 8.604278654
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 8.754176812
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 10.33840966
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 15.92074702
# 0 dual simplex iterations (0 in phase I)
# 20 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 22.34858087
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.83894293
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 6.913806785
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 82.65903666
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 17.24073083
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 53.88840368
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 7.042697834
# 0 dual simplex iterations (0 in phase I)
# 20 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 50.50427173
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 8.901015605
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 36.95351582
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 16.411978
# 0 dual simplex iterations (0 in phase I)
# 20 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 7.40127635
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 82.65733499
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 6.970719883
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 39.76720312
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 17.5126965
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 43.73717134
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 60.83301285
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 68.88010851
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 35.62460533
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 6.993735361
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 6.987592697
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 80.02619347
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 99.57417883
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 55.6937478
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 35.97578901
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 20.23528913
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 31.30188315
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.9124251
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 20.87676102
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 27.04562436
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 26.68362279
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 10.41560608
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 28.70182005
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 34.11326477
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 23.5599839
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 39.42944128
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 6.947250195
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 6.828723929
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 35.23444276
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 19.25895658
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 90.82337492
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 58.32309087
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 22.20612967
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 13.22435814
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 9.127088107
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 32.06529501
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 13.35682505
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 72.19747194
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 36.78887136
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 27.95626317
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 10.87601844
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 13.00202138
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 86.25204177
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 19.90220983
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 24.01340772
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 34.86549655
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 6.79466708
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 29.60521843
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 48.29704202
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 88.62825269
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 81.45806244
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 68.69202862
# 0 dual simplex iterations (0 in phase I)
# 15 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 17.07560024
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 14.84764199
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 18.46035504
# 0 dual simplex iterations (0 in phase I)
# 21 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 10.65525062
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 31.86679083
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 27.6708143
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 21.26559382
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 43.70329716
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 33.20503834
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 21.35740209
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 29.90714557
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 17.39708092
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 34.04971854
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 7.085829043
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 17.28060644
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 32.02934015
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 20.90349758
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 57.16232527
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 14.0329373
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 89.01089588
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 67.52493162
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 17.58384724
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 12.03271645
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 49.23068986
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 8.568201633
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 97.73180531
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 11.395486
# 0 dual simplex iterations (0 in phase I)
# 20 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 35.13220883
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 67.20648528
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 24.17603863
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 10.07845303
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 14.6496101
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 42.32102891
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 20.73640265
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 38.82619814
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 30.24738551
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 45.15635837
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 17.91353984
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 62.93803648
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 75.36517662
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 29.04423139
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 16.54068601
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 24.33184348
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 89.90603226
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 80.39628143
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 16.73987202
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 29.80284788
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 63.99100987
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 40.07616552
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 31.22262356
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 79.5440705
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 35.88044863
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 49.88953735
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 96.26986196
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 20.82017704
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 12.64409046
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 91.25677176
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 20.68717507
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 13.2517127
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 81.2074116
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 36.13773519
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 23.55930171
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 53.5626404
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 71.72354785
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 37.3600429
# 0 dual simplex iterations (0 in phase I)
# 19 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 33.08504485
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 22.65821384
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 67.08026791
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 81.30652517
# 0 dual simplex iterations (0 in phase I)
# 18 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 72.23111696
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 76.61298679
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 42.32699823
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 33.73645381
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 59.98360366
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 10.964517
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 54.19177806
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 61.43539626
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 37.62070266
# 0 dual simplex iterations (0 in phase I)
# 16 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 72.25477477
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations
# CPLEX 22.1.1.0: optimal solution; objective 15.64278149
# 0 dual simplex iterations (0 in phase I)
# 17 barrier iterations

# %%
W = ampl.get_variable("W").get_values().to_pandas()

# %%
import numpy as np
W_numpy = np.array(W.unstack().values)

# %%
#Qui bisogna modificare il nome in modo che venga come vogliamo noi (coè come c'è nel file)
np.save(W_NAME, W_numpy)

# %%
Y_pred = np.dot(X.T,W_numpy)

# %%
Y_pred.shape
# Out:
# (4367, 300)

# %% [markdown]
# ## Test on the first five nearest neighbours
#
# The dictionary computed in the previous step is fundamental to keep track of the words during the transformation.

# %%
import json

# Assuming your JSON file is named 'word_index_dict_common_words_left_right_p1.json'
file_path = NAME_JSON_FILE

# Open the JSON file and load it as a dictionary
with open(file_path, 'r') as json_file:
    word_index_dict = json.load(json_file)

# %%
word_index_dict.items()
# Out:
# dict_items([('deputati', 0), ('istituzionale', 1), ('chiamata', 2), ('visione', 3), ('certamente', 4), ('storico', 5), ('accedere', 6), ('out', 7), ('dito', 8), ('cronache', 9), ('mamma', 10), ('reti', 11), ('estero', 12), ('definizione', 13), ('misure', 14), ('revisione', 15), ('luce', 16), ('presentare', 17), ('prese', 18), ('teoria', 19), ('giulia', 20), ('battista', 21), ('tradizione', 22), ('omnibus', 23), ('registro', 24), ('spot', 25), ('triennale', 26), ('azzurro', 27), ('grafico', 28), ('valorizzazione', 29), ('immigrati', 30), ('esercito', 31), ('importo', 32), ('decidera', 33), ('nevicata', 34), ('avvenuta', 35), ('studio', 36), ('sui', 37), ('integrazione', 38), ('viene', 39), ('video', 40), ('leu', 41), ('infanzia', 42), ('dosi', 43), ('sistemi', 44), ('giudici', 45), ('monitoraggio', 46), ('italy', 47), ('contro', 48), ('sulle', 49), ('tiene', 50), ('spiegare', 51), ('cuore', 52), ('svolto', 53), ('rilasciato', 54), ('viste', 55), ('avversari', 56), ('ignazio', 57), ('dem', 58), ('sei', 59), ('tagli', 60), ('espansive', 61), ('guido', 62), ('dio', 63), ('accordi', 64), ('diceva', 65), ('film', 66), ('livello', 67), ('incarico', 68), ('lontani', 69), ('consiglio', 70), ('denuncia', 71), ('disponibilita', 72), ('del', 73), ('replica', 74), ('aula', 75), ('tengo', 76), ('commercianti', 77), ('notte', 78), ('arresto', 79), ('jobs', 80), ('centrosinistra', 81), ('incomprensibile', 82), ('h', 83), ('racconta', 84), ('nei', 85), ('riscontro', 86), ('costituito', 87), ('preso', 88), ('de', 89), ('molto', 90), ('forte', 91), ('venerdi', 92), ('resto', 93), ('nasce', 94), ('viminale', 95), ('venti', 96), ('potrebbe', 97), ('infn', 98), ('economista', 99), ('meana', 100), ('denunciato', 101), ('pirellone', 102), ('li', 103), ('numeri', 104), ('lettere', 105), ('comparto', 106), ('diversi', 107), ('sempre', 108), ('roventini', 109), ('vuole', 110), ('figure', 111), ('casini', 112), ('presentazione', 113), ('situazione', 114), ('amici', 115), ('mondo', 116), ('piazze', 117), ('giovedi', 118), ('anzi', 119), ('procedura', 120), ('pietro', 121), ('campidoglio', 122), ('rtl', 123), ('cos', 124), ('diversamente', 125), ('accordo', 126), ('musica', 127), ('presa', 128), ('degli', 129), ('importanti', 130), ('attaccare', 131), ('disastro', 132), ('concreto', 133), ('legislatura', 134), ('morire', 135), ('vicine', 136), ('omaggio', 137), ('indietro', 138), ('opposizioni', 139), ('esponenti', 140), ('libro', 141), ('stipendio', 142), ('colore', 143), ('portera', 144), ('lavorato', 145), ('assumere', 146), ('pensare', 147), ('abbia', 148), ('famiglie', 149), ('sociali', 150), ('agricoli', 151), ('olimpico', 152), ('stare', 153), ('verdi', 154), ('filomena', 155), ('sopportare', 156), ('propone', 157), ('scorso', 158), ('aprono', 159), ('designato', 160), ('magistrati', 161), ('atteggiamento', 162), ('ritorno', 163), ('ovvero', 164), ('paradosso', 165), ('attaccato', 166), ('aiuto', 167), ('rispettare', 168), ('concorrenti', 169), ('decisioni', 170), ('ministero', 171), ('birra', 172), ('addetti', 173), ('esperienze', 174), ('italiano', 175), ('palco', 176), ('pesce', 177), ('aumento', 178), ('pieno', 179), ('concluso', 180), ('biotestamento', 181), ('energetico', 182), ('chiari', 183), ('scarsa', 184), ('propongono', 185), ('bambini', 186), ('facile', 187), ('lazio', 188), ('dovuto', 189), ('valentina', 190), ('chiunque', 191), ('ideologia', 192), ('clan', 193), ('capitolo', 194), ('distanze', 195), ('promesso', 196), ('novembre', 197), ('destino', 198), ('emozione', 199), ('dicono', 200), ('semplice', 201), ('codice', 202), ('vecchi', 203), ('tratto', 204), ('comando', 205), ('antimafia', 206), ('fontana', 207), ('tutela', 208), ('b', 209), ('perfetto', 210), ('dimostrato', 211), ('prevede', 212), ('correre', 213), ('esprimere', 214), ('vilipendio', 215), ('mano', 216), ('flavia', 217), ('finalita', 218), ('classe', 219), ('acque', 220), ('modifiche', 221), ('richieste', 222), ('collegato', 223), ('nobel', 224), ('buono', 225), ('fra ...

# %%
#Funzione per avere i primi vicini di una parola a scelta
word = 'risultati'
src_word2id = word_index_dict
src_id2word = {v: k for k, v in src_word2id.items()}
tgt_word2id = word_index_dict
tgt_id2word = {v: k for k, v in tgt_word2id.items()}
src_emb = X.T
tgt_emb = Y_pred

# %%
def get_nn(word, src_emb, src_id2word, tgt_emb, tgt_id2word, K=5):
    print("Nearest neighbors of \"%s\":" % word)
    word2id = {v: k for k, v in src_id2word.items()}
    word_emb = src_emb[word2id[word]]
    scores = (tgt_emb / np.linalg.norm(tgt_emb, 2, 1)[:, None]).dot(word_emb / np.linalg.norm(word_emb))
    k_best = scores.argsort()[-K:][::-1]
    for i, idx in enumerate(k_best):
        print('%.4f - %s' % (scores[idx], tgt_id2word[idx]))

# %%
#Politic words (present in the dictionary)
src_words =  ['vecchio', 'ragazza', 'ragazzo', 'uomo', 'donna', 'comunista', 'fascista', 'fuoco']
tgt_words = ['vecchio', 'ragazza', 'ragazzo', 'uomo', 'donna', 'comunista', 'fascista', 'fuoco']

#Gender words
#src_words = ['gay', 'diverso', 'fuoco']
#tgt_words = ['gay', 'diverso', 'fuoco']

#Race words
#src_words = ['nero', 'casa', 'fuoco']
#tgt_words = ['nero', 'casa', 'fuoco']

# %% [markdown]
# With the next lines of code you can print which words are part of the vocabulary and which are not.

# %%
parole_presenti = []
parole_assenti = []

for parola in src_words:
    if parola in word_index_dict:
        parole_presenti.append(parola)
    else:
        parole_assenti.append(parola)

print("Words that are part of the dictionary:", parole_presenti)
print("Words that are not part of the dictionary:", parole_assenti)

# %%
def printing_NN(src_words, src_embeddings, src_id2word, K=5):
        for word in src_words:
                src_word = word
                get_nn(src_word, src_embeddings, src_id2word, src_embeddings, src_id2word, K=5)


# printing nearest neighbors in the source space
printing_NN(src_words, src_emb, src_id2word, K=5)

# printing nearest neighbors in the target space
printing_NN(tgt_words, tgt_emb, tgt_id2word, K=5)
# Out:
# Nearest neighbors of "vecchio":
# 1.0000 - vecchio
# 0.9993 - dai
# 0.9993 - nella
# 0.9993 - stato
# 0.9993 - sul
# Nearest neighbors of "ragazza":
# 1.0000 - ragazza
# 0.1682 - ministra
# 0.1664 - indignazione
# 0.1627 - privilegio
# 0.1625 - organizzata
# Nearest neighbors of "ragazzo":
# 1.0000 - ragazzo
# 0.9660 - tu
# 0.9660 - gara
# 0.9659 - battuta
# 0.9658 - nazionale
# Nearest neighbors of "uomo":
# 1.0000 - uomo
# 0.9981 - nell
# 0.9981 - nazionale
# 0.9981 - sull
# 0.9981 - liberi
# Nearest neighbors of "donna":
# 1.0000 - donna
# 0.1775 - clusit
# 0.1668 - disegno
# 0.1646 - varese
# 0.1617 - rosatellum
# Nearest neighbors of "comunista":
# 1.0000 - comunista
# 0.1811 - comprendere
# 0.1697 - pagare
# 0.1650 - flat
# 0.1648 - scongiurare
# Nearest neighbors of "fascista":
# 1.0000 - fascista
# 0.1644 - lezioni
# 0.1578 - inviare
# 0.1548 - viceministro
# 0.1485 - migliorata
# Nearest neighbors of "fuoco":
# 1.0000 - fuoco
# 0.2164 - mani
# 0.1884 - giusti
# 0.1556 - fini
# 0.1522 - lavinia
# Nearest neighbors of "vecchio":
# 1.0000 - vecchio
# 1.0000 - dai
# 1.0000 - cui
# 1.0000 - dem
# 1.0000 - sulla
# Nearest neighbors of "ragazza":
# 1.0000 - ragazza
# 0.9445 - cantone
# 0.9405 - cifre
# 0.9400 - casi
# 0.9359 - turismo
# Nearest neighbors of "ragazzo":
# 1.0000 - ragazzo
# 1.0000 - onorevole
# 1.0000 - disoccupati
# 1.0000 - liberare
# 1.0000 - definitivamente
# Nearest neighbors of "uomo":
# 1.0000 - uomo
# 1.0000 - fi
# 1.0000 - roberto
# 1.0000 - elezioni
# 1.0000 - torino
# Nearest neighbors of "donna":
# 1.0000 - donna
# 0.9140 - preferisco
# 0.9091 - venisse
# 0.9081 - catania
# 0.9076 - dimostrano
# Nearest neighbors of "comunista":
# 1.0000 - comunista
# 0.7658 - comprendere
# 0.7599 - produttive
# 0.7587 - cifre
# 0.7577 - periferia
# Nearest neighbors of "fascista":
# 1.0000 - fascista
# 0.6785 - criticato
# 0.6707 - africa
# 0.6705 - agricoltori
# 0.6669 - spallata
# Nearest neighbors of "fuoco":
# 1.0000 - fuoco
# 0.5596 - organizzare
# 0.5584 - fini
# 0.5569 - sanno
# 0.5518 - sostanziale

# %%
# Visualize multilingual embeddings

from uuid import uuid4


src_embeddings = X.T
tgt_embeddings = Y_pred






from sklearn.decomposition import PCA
pca = PCA(n_components=2, whiten=True)  # TSNE(n_components=2, n_iter=3000, verbose=2)
pca.fit(np.vstack([src_embeddings, tgt_embeddings]))
print('Variance explained: %.2f' % pca.explained_variance_ratio_.sum())

import matplotlib.pyplot as plt


def plot_similar_word(src_words, src_word2id, src_emb, tgt_words, tgt_word2id, tgt_emb, pca):

    Y = []
    word_labels = []
    for sw in src_words:
        Y.append(src_emb[src_word2id[sw]])
        word_labels.append(sw)
    for tw in tgt_words:
        Y.append(tgt_emb[tgt_word2id[tw]])
        word_labels.append(tw)

    # find tsne coords for 2 dimensions
    Y = pca.transform(Y)
    x_coords = Y[:, 0]
    y_coords = Y[:, 1]

    # display scatter plot
    plt.figure(figsize=(10, 8), dpi=80)
    plt.scatter(x_coords, y_coords, marker='x')

    for k, (label, x, y) in enumerate(zip(word_labels, x_coords, y_coords)):
        color = 'blue' if k < len(src_words) else 'red'  # src words in blue / tgt words in red
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points', fontsize=19,
                     color=color, weight='bold')

    plt.xlim(x_coords.min() - 0.2, x_coords.max() + 0.2)
    plt.ylim(y_coords.min() - 0.2, y_coords.max() + 0.2)
    plt.title('Visualization of the word embedding space')
    # Generate a random filename for the PNG
    filename = str(uuid4()) + ".png"

    # Save the plot as a PNG file
    plt.savefig(filename, format='png')

    plt.show()


# assert words in dictionaries
for sw in src_words:
    assert sw in src_word2id, '"%s" not in source dictionary' % sw
for tw in tgt_words:
    assert tw in tgt_word2id, '"%s" not in target dictionary' % sw

plot_similar_word(src_words, src_word2id, src_embeddings, tgt_words, tgt_word2id, tgt_embeddings, pca)
# Out:
# Variance explained: 1.00
